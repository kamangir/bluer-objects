# %% [markdown]
# # 🌀 alias
#
# [list_of_aliases](../bluer_objects/README/alias.py)

# %%
from bluer_options import string
from bluer_objects.README.alias import list_of_aliases

from bluer_objects import NAME
from bluer_objects.host import signature
from bluer_objects.logger import logger

logger.info(f"{'.'.join(signature())},\nbuilt on {string.pretty_date()}")
# Out:
# 🌀  bluer_objects-6.373.1.bluer_ai-12.381.1.bluer_objects-6.373.1.bluer_options-5.219.1.blueness-3.118.1.torch-2.2.2.Python 3.12.9.Darwin 23.6.0..Jupyter-Notebook,
# built on 25 December 2025, 00:53:40

# %% [markdown]
# ---

# %%
list_of_aliases(NAME, log=True)
# Out:
# 🌀  loaded 47 line(s) from /Users/kamangir/git/bluer-objects/bluer_objects/.abcli/alias.sh.
# ['ai',
#  'i',
#  'assets',
#  'create_test_asset',
#  'download',
#  'gif',
#  'cache',
#  'ref',
#  'tags',
#  'clone',
#  'cp',
#  'file',
#  'host',
#  'ls',
#  'lock',
#  'metadata',
#  'mlflow',
#  'mysql',
#  'objects',
#  'pdf',
#  'random',
#  'select',
#  'storage',
#  'upload',
#  'web']

# %% [markdown]
# ---

# %%
# END
