# %% [markdown]
# # WebDAV - request: ls
#
# https://chatgpt.com/c/6824f8d3-d9c0-8005-a7fa-d646f812f4b7

# %%
from bluer_options import string

from bluer_objects import objects
from bluer_objects.host import signature
from bluer_objects.testing import create_test_asset
from bluer_objects.storage import WebDAVRequestInterface
from bluer_objects import path
from bluer_objects.logger import logger

logger.info(f"{'.'.join(signature())},\nbuilt on {string.pretty_date()}")
# Out:
# 🌀  bluer_objects-6.121.1.bluer_ai-12.141.1.bluer_objects-6.121.1.bluer_options-5.97.1.torch-2.2.2.Python 3.12.9.Darwin 23.6.0..Jupyter-Notebook,
# built on 16 May 2025, 14:22:55

# %%
storage = WebDAVRequestInterface()

# %%
object_name = "test_storage_webdav_request-2025-05-16-14-18-39-9a705e"

# %% [markdown]
# ---

# %%
success, list_of_files = storage.ls(object_name=object_name, where="cloud")
assert success

logger.info("{} file(s)".format(len(list_of_files)))
for index, filename in enumerate(list_of_files):
    logger.info("#{: 3d}: {}".format(index+1, filename))
# Out:
# 🌀  16 file(s)
# 🌀  #  1: subfolder/that.yaml
# 🌀  #  2: subfolder/this.yaml
# 🌀  #  3: test-00.png
# 🌀  #  4: test-01.png
# 🌀  #  5: test-02.png
# 🌀  #  6: test-03.png
# 🌀  #  7: test-04.png
# 🌀  #  8: test-05.png
# 🌀  #  9: test-06.png
# 🌀  # 10: test-07.png
# 🌀  # 11: test-08.png
# 🌀  # 12: test-09.png
# 🌀  # 13: test.json
# 🌀  # 14: test.yaml
# 🌀  # 15: that.yaml
# 🌀  # 16: this.yaml

# %% [markdown]
# ---

# %%
# END
