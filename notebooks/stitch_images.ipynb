# %% [markdown]
# # 🌀 stitch_images
#
# [bluer_objects/logger/stitch.py](../bluer_objects/logger/stitch.py)

# %%
import numpy as np
import random

from bluer_options import string
from bluer_sandbox.notebooks import imshow
from bluer_objects.logger.stitch import stitch_images

from bluer_sandbox.host import signature
from bluer_sandbox.logger import logger

logger.info(f"{'.'.join(signature())},\nbuilt on {string.pretty_date()}")
# Out:
# 🌀  bluer_sandbox-5.293.1.bluer_ai-12.288.1.bluer_objects-6.307.1.bluer_options-5.181.1.blueness-3.118.1.torch-2.2.2.Python 3.12.9.Darwin 23.6.0..Jupyter-Notebook,
# built on 21 October 2025, 12:16:16

# %% [markdown]
# ---

# %%
count = 10
rng = np.random.default_rng()
list_of_images = [
       rng.integers(
           0, 
           256, 
           (
               random.randint(1, 512), 
               random.randint(1, 512), 
               random.choice([1, 3])
            ), 
            dtype=np.uint8
        ) for _ in range(count)
]

# %%
image = stitch_images(
    list_of_images, 
)

logger.info(f"image: {string.pretty_shape_of_matrix(image)}")
# Out:
# 🌀  image: 1202x1533x3:uint8

# %%
imshow(image)

# %% [markdown]
# ---

# %%
# END
