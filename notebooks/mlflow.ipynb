# %% [markdown]
# # 🌀 mlflow

# %%
from bluer_options import string

from bluer_objects.mlflow import create_filter_string
from bluer_objects.host import signature
from bluer_objects.logger import logger

logger.info(f"{'.'.join(signature())},\nbuilt on {string.pretty_date()}")
# Out:
# 🌀  bluer_objects-6.405.1.bluer_ai-12.392.1.bluer_objects-6.405.1.bluer_options-5.219.1.blueness-3.118.1.torch-2.2.2.Python 3.12.9.Darwin 23.6.0..Jupyter-Notebook,
# built on 06 January 2026, 11:32:56

# %% [markdown]
# ---

# %%
filter_string = "this=that,what,~who"

filter_string = create_filter_string(filter_string)
logger.info(f"filter_string: {filter_string}")
# Out:
# 🌀  filter_string: tags."this" = "that" and tags."what" = "True" and tags."who" = "False"

# %% [markdown]
# ---

# %%
# END
